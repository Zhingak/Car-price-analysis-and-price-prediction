# %%
#IMPORTING LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("CarPrice_data.csv")
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
round(df.describe(),2)
# Out:
#        car_ID  symboling  wheelbase  carlength  carwidth  carheight  \
# count  205.00     205.00     205.00     205.00    205.00     205.00
# mean   103.00       0.83      98.76     174.05     65.91      53.72
# std     59.32       1.25       6.02      12.34      2.15       2.44
# min      1.00      -2.00      86.60     141.10     60.30      47.80
# 25%     52.00       0.00      94.50     166.30     64.10      52.00
# 50%    103.00       1.00      97.00     173.20     65.50      54.10
# 75%    154.00       2.00     102.40     183.10     66.90      55.50
# max    205.00       3.00     120.90     208.10     72.30      59.80
#
#        curbweight  enginesize  boreratio  stroke  compressionratio  \
# count      205.00      205.00     205.00  205.00            205.00
# mean      2555.57      126.91       3.33    3.26             10.14
# std        520.68       41.64       0.27    0.31              3.97
# min       1488.00       61.00       2.54    2.07              7.00
# ...

# %%
#Checking for missing values.
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# # UNIVARIATE ANALYSIS OF THE CAR PRICE VARIABLE DETERMINANTS

# %%
df[['CarName']]
# Out:
#                       CarName
# 0          alfa-romero giulia
# 1         alfa-romero stelvio
# 2    alfa-romero Quadrifoglio
# 3                 audi 100 ls
# 4                  audi 100ls
# ..                        ...
# 200           volvo 145e (sw)
# 201               volvo 144ea
# 202               volvo 244dl
# 203                 volvo 246
# 204               volvo 264gl
#
# [205 rows x 1 columns]

# %%
import seaborn as sns

sns.catplot(data=df.head(50), y='CarName', kind='count').set(title='CAR MODEL DEMANDS')

# %% [markdown]
# Above visualization shows that audi 100ls, bmw 320i,bmw x3,Isuzu D-Max are in popular demand in Nigeria
# car market making them a major competitors with Honda Civic leading the competitors.

# %%
df[['CarName', 'price']].head(40)
# Out:
#                       CarName      price
# 0          alfa-romero giulia  13495.000
# 1         alfa-romero stelvio  16500.000
# 2    alfa-romero Quadrifoglio  16500.000
# 3                 audi 100 ls  13950.000
# 4                  audi 100ls  17450.000
# 5                    audi fox  15250.000
# 6                  audi 100ls  17710.000
# 7                   audi 5000  18920.000
# 8                   audi 4000  23875.000
# 9         audi 5000s (diesel)  17859.167
# 10                   bmw 320i  16430.000
# 11                   bmw 320i  16925.000
# 12                     bmw x1  20970.000
# 13                     bmw x3  21105.000
# 14                     bmw z4  24565.000
# 15                     bmw x4  30760.000
# 16                     bmw x5  41315.000
# 17                     bmw x3  36880.000
# 18           chevrolet impala   5151.000
# 19      chevrolet monte carlo   6295.000
# 20        chevrolet vega 2300   6575.000
# 21              dodge rampage   5572.000
# ...

# %%
#Table showing car brand price in Nigeria
price = pd.pivot_table(data=df,index='CarName',values='price', aggfunc=np.sum)
price
# Out:
#                             price
# CarName
# Nissan versa               5499.0
# alfa-romero Quadrifoglio  16500.0
# alfa-romero giulia        13495.0
# alfa-romero stelvio       16500.0
# audi 100 ls               13950.0
# ...                           ...
# volvo 246                 22470.0
# volvo 264gl               41045.0
# volvo diesel              18950.0
# vw dasher                 11595.0
# vw rabbit                  9980.0
#
# [147 rows x 1 columns]

# %%
#Plot to display the mostly priced car brands in Nigeria.
plt.style.use('bmh')
price.head(30).plot(kind='barh', title='CAR BRANDS PRICES')
# Out:
# <AxesSubplot:title={'center':'CAR BRANDS PRICES'}, ylabel='CarName'>

# %% [markdown]
# The visualization above shows that bmw x3 is the most priced brand in Nigeria car market.

# %%
#Average car price in the market.

df[['price']].mean()
# Out:
# price    13276.710571
# dtype: float64

# %%
#Minimum or least car price in the market.
df[['price']].min()
# Out:
# price    5118.0
# dtype: float64

# %%
#Maximium car price in the market.

df[['price']].max()
# Out:
# price    45400.0
# dtype: float64

# %%
sns.catplot(data=df.head(30), y='price', kind='count').set(title='CAR PRICE RATE')

# %% [markdown]
# # MULTIVARIATE/BIVARIATE ANALYSIS OF THE CAR MARKET

# %%
data = df[['CarName','fueltype','doornumber','carbody']].head(30)
data
# Out:
#                       CarName fueltype doornumber      carbody
# 0          alfa-romero giulia      gas        two  convertible
# 1         alfa-romero stelvio      gas        two  convertible
# 2    alfa-romero Quadrifoglio      gas        two    hatchback
# 3                 audi 100 ls      gas       four        sedan
# 4                  audi 100ls      gas       four        sedan
# 5                    audi fox      gas        two        sedan
# 6                  audi 100ls      gas       four        sedan
# 7                   audi 5000      gas       four        wagon
# 8                   audi 4000      gas       four        sedan
# 9         audi 5000s (diesel)      gas        two    hatchback
# 10                   bmw 320i      gas        two        sedan
# 11                   bmw 320i      gas       four        sedan
# 12                     bmw x1      gas        two        sedan
# 13                     bmw x3      gas       four        sedan
# ...

# %%
#Most used fuel type in the Nigerian car market.

df[['fueltype']].value_counts()
# Out:
# fueltype
# gas         185
# diesel       20
# dtype: int64

# %%
plt.style.use('ggplot')

df[['fueltype']].value_counts().plot(kind='pie', autopct='%1.1f%%',title='FUEL TYPE USED')
# Out:
# <AxesSubplot:title={'center':'FUEL TYPE USED'}, ylabel='None'>

# %% [markdown]
# Plot above shows gas as the mostly used fueltype in Nigeria.

# %%
df[['carbody','doornumber']].value_counts()
# Out:
# carbody      doornumber
# sedan        four          80
# hatchback    two           60
# wagon        four          25
# sedan        two           16
# hatchback    four          10
# hardtop      two            8
# convertible  two            6
# dtype: int64

# %%
#Plot showing body-type and door-numbers used in Nigeria.

df[['carbody','doornumber']].value_counts().plot(kind='bar', color='orange')
# Out:
# <AxesSubplot:xlabel='carbody,doornumber'>

# %% [markdown]
# The data and plot shows that Four doors sedan cars are higly dominant/sold
# and two doors hatchback come next to mostly demanded in the market
# with convertible cars in lowest demand in the Nigerian market.

# %%
Eng = df[['CarName','drivewheel','enginelocation','enginesize']]
Eng
# Out:
#                       CarName drivewheel enginelocation  enginesize
# 0          alfa-romero giulia        rwd          front         130
# 1         alfa-romero stelvio        rwd          front         130
# 2    alfa-romero Quadrifoglio        rwd          front         152
# 3                 audi 100 ls        fwd          front         109
# 4                  audi 100ls        4wd          front         136
# ..                        ...        ...            ...         ...
# 200           volvo 145e (sw)        rwd          front         141
# 201               volvo 144ea        rwd          front         141
# 202               volvo 244dl        rwd          front         173
# 203                 volvo 246        rwd          front         145
# 204               volvo 264gl        rwd          front         141
#
# [205 rows x 4 columns]

# %%
#Minimum engine size in Nigeria
Eng[['enginesize']].min()
# Out:
# enginesize    61
# dtype: int64

# %%
#Maximum engine size in Nigeria
Eng[['enginesize']].max()
# Out:
# enginesize    326
# dtype: int64

# %%
#The average engine size in Nigeria
Eng[['enginesize']].mean()
# Out:
# enginesize    126.907317
# dtype: float64

# %%
df[['enginesize','drivewheel']].value_counts()
# Out:
# enginesize  drivewheel
# 122         fwd           15
# 97          fwd           14
# 92          fwd           13
# 110         fwd           12
# 90          fwd           12
# 98          fwd           10
# 109         fwd            8
# 141         rwd            7
# 146         rwd            6
# 108         fwd            6
# 121         fwd            6
# 152         rwd            6
# 108         4wd            5
# 91          fwd            5
# 120         rwd            5
# 98          rwd            4
# 183         rwd            4
# 156         fwd            4
# 130         rwd            4
# 136         fwd            4
# 70          rwd            3
# 194         rwd            3
# 171         rwd            3
# 164         rwd            3
# 209         rwd            3
# 181         fwd            3
#             rwd            3
# 140         rwd            2
# 132         fwd            2
# 134         rwd            2
# 234         rwd            2
# ...

# %%
df[['enginesize','drivewheel']].value_counts().plot(kind='line',color='blue')
# Out:
# <AxesSubplot:xlabel='enginesize,drivewheel'>

# %% [markdown]
# Car engine sizes of 122,97,92,110,90 and 98 on fwd are in high demand and popular in the Nigerian
# market contributing to price determinant.

# %%
df.loc[[13]]
# Out:
#     car_ID  symboling CarName fueltype aspiration doornumber carbody  \
# 13      14          0  bmw x3      gas        std       four   sedan
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 13        rwd          front      101.2  ...         164        mpfi
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 13       3.31    3.19              9.0        121     4250      21
#
#     highwaympg    price
# 13          28  21105.0
#
# [1 rows x 26 columns]

# %% [markdown]
# # IDENTIFYING REGRESSION MODEL

# %%
sns.pairplot(df)

# %%
#Table showing the variables significant in car price prediction and how they correlate.


df_num = df.corr()
df_num
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
plt.style.use('classic')
df.plot.scatter(x='highwaympg',y='citympg')
# Out:
# <AxesSubplot:xlabel='highwaympg', ylabel='citympg'>

# %%
#plot to identify the linear regression in the data.
plt.style.use('ggplot')
sns.lmplot(x='highwaympg',y='citympg',data=df)

# %%
import warnings
warnings.filterwarnings('ignore')

sns.distplot(df['price'],bins=100, hist_kws={'alpha':0.5}).set(title='PRICE DISTIBUTION')
# Out:
# [Text(0.5, 1.0, 'PRICE DISTIBUTION')]

# %%
#Heatmap showing correlation of modelling features
sns.heatmap(df_num)
# Out:
# <AxesSubplot:>

# %%
#Strongest correlation with car price  #Important Features
important_feat = df_num
print(f'There are {len(important_feat)} strongly correlated features with car price:')
# Out:
# There are 16 strongly correlated features with car price:

# %%
sns.pairplot(data=df_num)

# %% [markdown]
# # FEATURES ENGINEERING

# %%
#Arrays with training features

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#Features modelling by splitting dataset into Input(x) and Output(y) variables
x = df[['car_ID', 'symboling','wheelbase',
       'carlength', 'carwidth', 'carheight', 'curbweight',
        'enginesize', 'boreratio', 'stroke',
       'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg']]

# %%
#Prediction variable
y = df[['price']]

# %% [markdown]
# # Training and Testing The Features

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor   #Multi Layer Perceptron /deep learning
from sklearn.ensemble import RandomForestRegressor


#Train test split
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Instantiate Model

# %%
lm = LinearRegression()    #default hyperparameters 
modelNN = MLPRegressor()
modelRF = RandomForestRegressor()

# %%
#Splitting dataset into training and testing
x_test,x_train,y_test,y_train = train_test_split(x,y, test_size=0.4, random_state=85)

# %% [markdown]
# # LINEAR MODEL BUILDING

# %% [markdown]
# # Testing Model

# %%
x_test
# Out:
#      car_ID  symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 171     172          2       98.4      176.2      65.6       52.0        2714
# 56       57          3       95.3      169.0      65.7       49.6        2380
# 65       66          0      104.9      175.0      66.1       54.4        2670
# 129     130          1       98.4      175.7      72.3       50.5        3366
# 120     121          1       93.7      157.3      63.8       50.6        1967
# ..      ...        ...        ...        ...       ...        ...         ...
# 51       52          1       93.1      159.1      64.2       54.1        1900
# 196     197         -2      104.3      188.8      67.2       56.2        2935
# 141     142          0       97.2      172.0      65.4       52.5        2145
# 160     161          0       95.7      166.3      64.4       53.0        2094
# 106     107          1       99.2      178.5      67.9       49.7        3139
#
# ...

# %%
y_test
# Out:
#        price
# 171  11549.0
# 56   11845.0
# 65   18280.0
# 129  31400.5
# 120   6229.0
# ..       ...
# 51    6095.0
# 196  15985.0
# 141   7126.0
# 160   7738.0
# 106  18399.0
#
# [123 rows x 1 columns]

# %% [markdown]
# # Training the Model

# %%
lm.fit(x_train, y_train)
modelNN.fit(x_train, y_train)
modelRF.fit(x_train, y_train)


#cross validation
# Out:
# RandomForestRegressor()

# %%
#Rsquared score
#measuring error in prediction and comparing models with each other based on their
#generalizability

from sklearn.metrics import r2_score

# %%
lm.coef_
# Out:
# array([[-1.64696941e+01,  2.82337968e+02,  1.48431000e+02,
#         -1.27952371e+02,  5.82611363e+02,  5.26035510e+02,
#          6.43047697e-01,  1.20411939e+02,  3.05618005e+02,
#         -2.90830134e+03,  4.33136321e+02,  3.72565521e+01,
#          3.06025081e+00, -5.37568442e+02,  3.45436240e+02]])

# %%
print(lm.score(x_test,y_test))
print(modelNN.score(x_test,y_test))
print(modelRF.score(x_test,y_test))
# Out:
# 0.8117493270438878
# 0.15438040911367346
# 0.9175956033421223

# %% [markdown]
# # Import Sklearn Metrics

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
LRpred = lm.predict(x_test)
NNpred = modelNN.predict(x_test)
RFpred = modelRF.predict(x_test)

# %% [markdown]
# # ERROR EVALUATIONS METRICS

# %%
#compare x-test prediction(predicted output) to the actual prediction (y_test)
#actual test output

# %%
print(mean_squared_error(LRpred, y_test))
print(mean_squared_error(NNpred, y_test))
print(mean_squared_error(RFpred, y_test))
# Out:
# 9976505.689071212
# 44814334.66766045
# 4367091.597348283

# %%
print(mean_absolute_error(LRpred, y_test))
print(mean_absolute_error(NNpred, y_test))
print(mean_absolute_error(RFpred, y_test))
# Out:
# 2356.8319199539264
# 5306.84927958221
# 1403.6917317073169

# %%
print(np.sqrt(mean_squared_error(LRpred, y_test)))
print(np.sqrt(mean_squared_error(NNpred, y_test)))
print(np.sqrt(mean_squared_error(RFpred, y_test)))
# Out:
# 3158.5606989689486
# 6694.35095193406
# 2089.75874142167

# %%
print(r2_score(LRpred, y_test))
print(r2_score(NNpred, y_test))
print(r2_score(RFpred, y_test))
# Out:
# 0.8090944235749638
# -32.26644583458342
# 0.9162619453908245

# %% [markdown]
# Our r2_score for Linear Model Regression(LR) and Random Forest Regression(RF) are 80% and 91%
# showing an optimal model performance. RF model will be best choice for good car price prediction.

# %%
LRpred
# Out:
# array([[12237.9066413 ],
#        [ 9430.66738305],
#        [18221.52941954],
#        [37031.16505209],
#        [ 5491.89700203],
#        [22614.10286052],
#        [ 7719.97542154],
#        [11397.45547686],
#        [27408.83633182],
#        [ 7054.19529653],
#        [ 5894.8931544 ],
#        [ 6308.7849334 ],
#        [16450.01711831],
#        [15022.64152799],
#        [11315.59987307],
#        [18361.01680303],
#        [18966.23118336],
#        [ 7163.23951675],
#        [18354.06703736],
#        [17749.15600457],
#        [ 6578.20617344],
#        [23347.19548507],
#        [32150.02210345],
#        [28568.53454786],
#        [ 5391.97919987],
#        [14604.63065292],
#        [10949.83528536],
#        [12166.02925482],
#        [10837.60785592],
#        [20395.50582511],
#        [14992.72130029],
#        [ 6018.81535332],
#        [ 6313.43022291],
#        [18748.46844492],
#        [ 9550.53394571],
#        [11779.02167144],
#        [10102.94203227],
# ...

# %%
#Comparing y_test to the prediction to find the residuals
plt.scatter(y_test, LRpred)

# %%
#histogram distribution of the residuals

sns.distplot(y_test- LRpred/10**2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Evaluate prediction accuracy
from sklearn.metrics import accuracy_score
accuracy = lm.score(x_test,LRpred)

# %%
accuracy
# Out:
# 1.0

# %% [markdown]
# # INSIGHTS AND OBSERVATIONS
